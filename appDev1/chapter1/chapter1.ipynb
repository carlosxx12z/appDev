# %% [markdown]
# exercise 1:
#           print('Hello world!')
#           # python is case sensitive
#
#           print("hello world!")
#           #print is a function therfore you have to enclosed it with parenthesis
#
#           print('Hello world!')
#           #this line of code is missing \" ' \"
#
#           print('Hello world!')
#           #if we wanted to print something is should only be enclose between two single qoute or two double qoute
#
# exercise 2:
#
#           x = 43
#           x = x + 1
#           print(x)
#           # the answer is 44 since we pass x = 43 with x = x + 1 therfore the value of x is now 44 this is called override
#
# exercise 3:
#           x = 43
#           x = x + 1
#           print(x)
#
#           # in line 2 x = X + 1 the error here is the capetalized "X" which has not been defined in the first block, x and X is not the same since python is case senstive

# %%
print('Hello world!')
# python is case sensitive
# Out:
# Hello world!

# %%
print("hello world!")
#print is a function therfore you have to enclosed it with parenthesis
# Out:
# hello world!

# %%
print('Hello world!')
#this line of code is missing \" ' \"
# Out:
# Hello world!

# %%
print('Hello world!')
#if we wanted to print something is should only be enclose between two single qoute or two double qoute
# Out:
# Hello world!

# %%
x = 43
x = x + 1
print(x)
# the answer is 44 since we pass x = 43 with x = x + 1 therfore the value of x is now 44 this is called override
# Out:
# 44

# %%
x = 43
x = x + 1
print(x)

# in line 2 x = X + 1 the error here is the capetalized "X" which has not been defined in the first block, x and X is not the same since python is case senstive
# Out:
# 44
