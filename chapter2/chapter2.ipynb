# %% [markdown]
# Chapter 2 Exercises

# %% [markdown]
# Exercise 1

# %%
name = input("Enter your name: ")
print(f"welcome: {name}!!")
# Out:
# Enter your name: Jose Carlos Dairo
# welcome: Jose Carlos Dairo!!

# %% [markdown]
# Exercise 2

# %%
hours = int(input("Enter hours: "))
rate = float(input("Enter rate: "))
pay = float(hours) * rate
print(f"gross pay is: {pay}")
# Out:
# Enter hours: 35
# Enter rate: 2.75
# gross pay is:  96.25

# %% [markdown]
# Exercise 3

# %%
width = 12
height = 12.0
print(width)
print(height)
print(type(width/2))
print(type(width/2.0))
print(type(height/3))
print(type(1+2*5))
# Out:
# 12
# 12.0
# <class 'float'>
# <class 'float'>
# <class 'float'>
# <class 'int'>

# %% [markdown]
# Exercise 4

# %%
sq = int(input("Enter a number: "))
res = sq*sq
print(f"The sqaure root of {sq} is {res}")
# Out:
# Enter a number: 11
# The sqaure root of 11 is 121

# %%
cel = input("Enter celcius: ")
fah = (1.8 * float(cel)) + 32
print(f"{cel} degree celcius to farenhiet is: {fah}")
# Out:
# Enter celcius: 35
# 35 degree celcius to farenhiet is: 95.0
